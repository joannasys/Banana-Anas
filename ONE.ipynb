# %%
import glob
import librosa
from scipy.io import wavfile
import re
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from PIL import Image

# %%
MMS = MinMaxScaler()

#spectrogram = []
y = []

for filename in glob.iglob('./train/training/*'):
    for i,filename_wav in enumerate(glob.iglob(filename+'/*')):
      
        sample_rate, samples = wavfile.read(filename_wav)
        S = librosa.feature.melspectrogram(samples, sr=sample_rate, n_mels=128)
        log_S = librosa.power_to_db(S, ref=np.max)
        if log_S.shape == (128,32):         # only train data that have 32 columns
            
            log_S_S = MMS.fit_transform(log_S)   # Normalisation of values
            X = np.stack((log_S_S,)*3,axis=2)     
            rescaled = (255.0 /X.max() * (X - X.min())).astype(np.uint8)
            im = Image.fromarray(rescaled)
            im.save('./train/image/'+str(label)+'_'+str(filename_wav[23:-4])+'.jpeg')
            
            #spectrogram.append(log_S_S)   # list of spectrogram array
            
        
            label = re.search('[^/]+$',filename).group()   # class
            labels.append(label)     # list of labels
            
        if i%100 == 0:
            print('saved image {}'.format(i+100))
# Out:
# saved image 100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-899eded222a4> in <module>()
#       8
#       9         sample_rate, samples = wavfile.read(filename_wav)
# ---> 10         S = librosa.feature.melspectrogram(samples, sr=sample_rate, n_mels=128)
#      11         log_S = librosa.power_to_db(S, ref=np.max)
#      12         if log_S.shape == (128,32):
#
# ~/anaconda/envs/python3/lib/python3.6/site-packages/librosa/feature/spectral.py in melspectrogram(y, sr, S, n_fft, hop_length, power, **kwargs)
#    1389
#    1390     # Build a Mel filter
# -> 1391     mel_basis = filters.mel(sr, n_fft, **kwargs)
#    1392
#    1393     return np.dot(mel_basis, S)
#
# ~/anaconda/envs/python3/lib/python3.6/site-packages/librosa/filters.py in mel(sr, n_fft, n_mels, fmin, fmax, htk, norm)
#     246         # lower and upper slopes for all bins
# ...
